# %% [markdown]
# In this file, we:
#
# - Separate our dataset in train (&test9 and validation set
# - Based on text analysis we create features for all projects
#
# **Result: agg_data5**

# %%
import fitz  # PyMuPDF
import numpy as np
import os
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
from PyPDF2 import PdfReader
from sklearn.feature_extraction.text import CountVectorizer

agg_data = pd.read_csv("agg_data4.csv")
agg_data.head()
# Out:
#                               pdf  \
# 0    %C3%84gypten_Qena_2022_D.pdf
# 1  %C3%84gypten_Umwelt_2022_D.pdf
# 2  %C3%84thiopien_Gavi_2022_D.pdf
# 3           Afrika_TCX_2012_D.pdf
# 4       Albanien_Elbasan_2011.pdf
#
#                                         project_name  multiple_phases  \
# 0   Kommunale Wasserver- und Abwasserentsorgung Qena                0
# 1  Förderung von Umweltschutzmaßnahmen der privat...                0
# 2  Impfprogrammförderung in Äthiopien in Zusammen...                0
# 3                             Lokalwährungsfonds TCX                0
# 4  Wirtschaftsförderung durch Ausbau kommunaler I...                0
#
#    number_countries  eval_year  number_sectors  number_subsectors  \
# 0                 1       2022               1                  1
# 1                 1       2022               1                  1
# 2                 1       2022               1                  1
# 3                 1       2012               1                  1
# 4                 1       2011               1                  1
#
#    mean_investment  number_funding_source  number_carrier_type  ...  \
# 0       12670000.0                      1                    1  ...
# 1       25780000.0                      1                    1  ...
# 2       10000000.0                      1                    1  ...
# 3       90000000.0                      1                    1  ...
# 4       10600000.0                      1                    1  ...
#
#    relevance  coherence  effectivity  efficiency  impact  sustainability  \
# 0        2.0        3.0          3.0         2.0     3.0             3.0
# 1        3.0        2.0          3.0         3.0     4.0             3.0
# 2        2.0        3.0          3.0         3.0     3.0             2.0
# 3        2.0        NaN          1.0         2.0     1.0             2.0
# 4        3.0        NaN          4.0         4.0     4.0             3.0
#
#                                                  url cluster  \
# 0  https://www.kfw-entwicklungsbank.de/PDF/Evalui...       3
# 1  https://www.kfw-entwicklungsbank.de/PDF/Evalui...       3
# 2  https://www.kfw-entwicklungsbank.de/PDF/Evalui...       3
# 3  https://www.kfw-entwicklungsbank.de/PDF/Evalui...       7
# 4  https://www.kfw-entwicklungsbank.de/Evaluierun...       2
#
#    invest_plan_vs_actual  adaptive_management
# 0               0.186092                    1
# 1               0.551440                    1
# 2                    NaN                    0
# 3                    NaN                    0
# 4               0.645367                    1
#
# [5 rows x 21 columns]

# %% [markdown]
# First we extract the text from each pdf and put create a new column in agg_data.

# %%
def extract_text_from_pdf(pdf_path):
    try:
        pdf_document = fitz.open(pdf_path)
        text = ""
        for page_num in range(len(pdf_document)):
            page = pdf_document.load_page(page_num)
            text += page.get_text()
        return text
    except Exception as e:
        print(f"Error reading {pdf_path}: {e}")
        return ""

# Pdf directory
current_directory = os.getcwd()
folder_path = os.path.join(current_directory, 'pdf_reports')

agg_data['pdf_text'] = agg_data['pdf'].apply(lambda pdf: extract_text_from_pdf(os.path.join(folder_path, pdf)))

# %% [markdown]
# Now, we clean the texts in the following way.

# %%
def preprocess_text(text):
    text = text.lower()  # Lowercase
    text = re.sub(r'\d+', '', text)  # Removing numbers
    text = text.replace('\n', '')  # Removing new line characters
    text = text.translate(str.maketrans('', '', string.punctuation))  # Removing punctuation
    return text

agg_data['pdf_text'] = agg_data['pdf_text'].apply(preprocess_text)

# %% [markdown]
# Next, we extract other features:
# - word_count: total number of words in pdf
# - character_count: total number of characters in pdf
# - word_density: average length of words used

# %%
def word_count(text):
    words = text.split()
    return len(words)

def character_count(text):
    return len(text)

def word_density(text):
    words = text.split()
    if len(words) == 0:
        return 0
    return sum(len(word) for word in words) / len(words)

agg_data['word_count'] = agg_data['pdf_text'].apply(word_count)
agg_data['character_count'] = agg_data['pdf_text'].apply(character_count)
agg_data['word_density'] = agg_data['pdf_text'].apply(word_density)

# %% [markdown]
# Before moving on with feature engineering, we separate the complete dataset in training, testing and validation. We use train and test for feature engineering and the validation set for final model evaluation. Since we have a limited amount of observations, we use only 10% for validation purposes:

# %%
validation_data = agg_data.sample(frac=0.1, random_state = 123)
train_test_data = agg_data.drop(validation_data.index)
train_test_data.shape, validation_data.shape
# Out:
# ((665, 25), (74, 25))

# %% [markdown]
# We create several functions for text extraction from the pdf files.

# %%
current_directory = os.getcwd()
folder_path = os.path.join(current_directory, 'pdf_reports')

def stopwords(text, remove_stopwords=True):    
    if remove_stopwords == True:
        # Remove German stopwords
        stopwords_german = set(stopwords.words('german'))
        words = text.split()
        filtered_words = [word for word in words if word.lower() not in stopwords_german]

        # Join the filtered words back into a single string
        text = ' '.join(filtered_words)
    else:
        pass

    return text

def extract_text(pdf_path):
    reader = PdfReader(pdf_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text()
    return text

def read_files(agg_data, score, remove_stopwords=True):
    df = agg_data[agg_data["overall_rating"].isin(score)]
    pdfs = list(df["pdf"])
    text_dict = {}
    for file in pdfs:
        pdf_path = os.path.join(folder_path, file)
        text = extract_text(pdf_path)
        processed_text = stopwords(text, remove_stopwords)
        text_dict[file] = processed_text
    return text_dict

def most_used_words(arrays, k, zero_threshold):
    # Finds the words that are used most often on average
    # Zero_threshold makes sure that only words are filtered that are used in a lot of reports
    
    # 1. Stacks arrays and calcaulate mean values for every column
    stacked_arrays = np.vstack(arrays)
    mean_values = np.mean(stacked_arrays, axis=0)
    
    # 2. Calculate the proportion of zeros in each column and filter out words with too many zeros
    column_totals = stacked_arrays.shape[0]
    zero_counts = np.sum(stacked_arrays == 0, axis=0)
    zero_ratio = zero_counts / column_totals
    idx = np.where(zero_ratio < zero_threshold)[0]
    mean_values[idx] = np.nan
    
    # 3. Sorting indices by mean values in descending order
    sorted_idx = np.argsort(-mean_values)
    highest_idx = sorted_idx[:k]
    return highest_idx, mean_values

# %% [markdown]
# We try to identify token-based features by looking for similarities in word use for different rating groups:

# %%
# First we use this function to exract all texts for a specific rating
result = read_files(train_test_data, [1,2], remove_stopwords=False)
texts = list(result.values())

# Bag of Words
vectorizer = CountVectorizer(ngram_range=(3, 3))
X = vectorizer.fit_transform(texts)

# List of arrays for similar_features function
arrays = [row for row in X.toarray()]

# Extracting the words that are used most often
idx_mean, most = most_used_words(arrays, 250, 0.01)

feature_names = vectorizer.get_feature_names_out()

print("Most Frequently Used Words:")
print(feature_names[idx_mean])
print(" ")
print("Frequency of Most Used Words:")
print(most[idx_mean])
# Out:
# Most Frequently Used Words:
# ['nach dac kriterien' 'bewertung nach dac' 'mit hoher wahrscheinlichkeit'
#  'wirksamkeit des vorhabens' 'des vorhabens wird' 'ex post evaluierung'
#  'vorhabens wird mit' 'wird mit hoher'
#  'entwicklungspolitische wirksamkeit des' 'im rahmen der'
#  'die bisher positive' 'positive entwicklungspolitische wirksamkeit'
#  'nachhaltigkeit die bisher' 'bisher positive entwicklungspolitische'
#  'zum zeitpunkt der' 'unter den erwartungen' 'diese stufe ist'
#  'übergeordnete entwicklungspolitische wirkungen'
#  'die negativen ergebnisse' 'stufe ist auch' 'wirkungen als auch'
#  'gute nachhaltigkeit die' 'zutreffend wenn die' 'ist auch zutreffend'
#  'auch zutreffend wenn' 'im rahmen des' 'aus heutiger sicht'
#  'relevanz effektivität effizienz' 'als auch die'
#  'effektivität effizienz übergeordnete' 'das vorhaben ist'
#  'des vorhabens ist' 'ex post evaluierungsbericht' 'deutlich über den'
#  'bis zum evaluierungszeitpunkt' 'einen beitrag zur'
#  'über den erwartungen' 'ist eher verschlechtert' 'zur beurteilung des'
#  'liegendes ergebnis stufe' 'ist nutzlos bzw' 'situation ist eher'
#  'erwartungen aber es' 'nutzlos bzw die' 'die situation ist'
#  'bzw die situation' 'voll den erwartungen' 'sind wie folgt'
#  'anhand der folgenden' 'des vorhabens nach' 'beurteilung des vorhabens'
#  'vorhabens nach den' 'den erwartungen liegendes' 'nach den kriterien'
#  'wird anhand der' 'vorhaben ist nutzlos' 'erwartungen liegendes ergebnis'
#  'die stufen ein' 'als auch zur' 'eher verschlechtert die'
#  'die stufen der' 'deutlich unter den' 'und nicht mehr' 'stufen ein nicht'
#  'werden kann wenn' 'kann wenn die' 'wird aus einer'
#  'das kriterium nachhaltigkeit' 'methodik der erfolgsbewertung'
#  'bleiben diese stufe' 'ein vorhaben nur' 'stufe sehr gutes'
#  'zur verbesserung der' 'noch positiv bleiben' 'skala wird aus'
#  'ist bis zum' 'auch zur abschließenden' 'positiv bleiben diese'
#  'sehr gutes deutlich' 'zur methodik der' 'auf der sechsstufigen'
#  'nicht mehr den' 'aber noch positiv' 'kriterium nachhaltigkeit wird'
#  'dass ein vorhaben' 'den erwartungen aber' 'das was man' 'und wird sich'
#  'gutes deutlich über' 'der sechsstufigen skala'
#  'einer projektspezifisch zu' 'aus einer projektspezifisch'
#  'nachhaltigkeit wird anhand' 'den kriterien relevanz'
#  'zufriedenstellendes ergebnis liegt' 'wird eine sechsstufige'
#  'erfolgreiches die stufen' 'wird sich mit' 'aber mit hoher'
#  'sechsstufigen skala wird' 'der stufe genügen' 'liegt deutlich unter'
#  'fortbestehen oder sogar' 'stufe das vorhaben' 'sich mit hoher'
#  'ergebnis stufe gutes' 'den erwartungen und' 'die stufen eine'
#  'stufe genügen wird' 'die stufen kennzeichnen' 'ein erfolgreiches die'
#  'stufe eindeutig unzureichendes' 'gutes voll den'
#  'unverändert fortbestehen oder' 'stufen eine nicht' 'sich aber mit'
#  'erwartungen und es' 'verschlechtert die stufen'
#  'ergebnis ohne wesentliche' 'eine positive bzw' 'wird sich aber'
#  'und das vorhaben' 'vorhabens ist bis' 'damit eine positive'
#  'nicht erfolgreiche bewertung' 'kennzeichnen eine positive'
#  'bzw nicht erfolgreiche' 'wirksamkeit wird eine' 'rating zur beurteilung'
#  'nachhaltigkeit mindestens als' 'die gesamtbewertung auf'
#  'die nachhaltigkeit mindestens' 'zurückgehen aber noch'
#  'ohne wesentliche mängel' 'auch die nachhaltigkeit'
#  'stufen kennzeichnen eine' 'gesamtbewertung auf der' 'dabei ist zu'
#  'der folgenden vierstufigen' 'bewertung das kriterium'
#  'zurückgehen aber insgesamt' 'eine sechsstufige skala'
#  'wesentliche mängel stufe' 'einiger positiver teilergebnisse'
#  'erfolgreiche bewertung das' 'liegt unter den'
#  'kriterien relevanz effektivität' 'wie folgt belegt'
#  'folgenden vierstufigen skala' 'nicht verbessern diese'
#  'auch nicht verbessern' 'stufe gutes voll' 'erfolgsbewertung rating zur'
#  'stufen der gesamtbewertung' 'nur dann als' 'der erfolgsbewertung rating'
#  'genügen wird die' 'zu berücksichtigen dass' 'ergebnisse die negativen'
#  'eindeutig unzureichendes ergebnis' 'nur geringfügig zurückgehen'
#  'eingeschätzt wird sich' 'nachhaltigkeitsstufe gute nachhaltigkeit'
#  'nicht ausreichend und' 'gebildet die stufen' 'effektivität und die'
#  'belegt stufe sehr' 'es dominieren die' 'verbessern diese stufe'
#  'das vorhaben damit' 'ausreichend eingeschätzt wird'
#  'geringfügig zurückgehen aber' 'was man erwarten'
#  'aber insgesamt deutlich' 'man erwarten kann'
#  'entwicklungspolitische wirkungen als'
#  'nachhaltigkeitsstufe nicht ausreichende' 'ergebnis liegt unter'
#  'die wirkungen auf' 'vorhaben damit eine' 'folgt belegt stufe'
#  'ergebnisse deutlich stufe' 'als nicht ausreichend'
#  'ausreichend und wird' 'vorhaben nur dann' 'aber es dominieren'
#  'berücksichtigen dass ein' 'wenn die nachhaltigkeit'
#  'die nachhaltigkeit eines' 'abschließenden gesamtbewertung der'
#  'zur abschließenden gesamtbewertung' 'einzelkriterien gebildet die'
#  'eine nicht positive' 'deutlich zurückgehen aber' 'gewichtung der fünf'
#  'zum evaluierungszeitpunkt nicht' 'ist zu berücksichtigen'
#  'oder sogar zunehmen' 'stufe bewertet werden' 'und die wirkungen'
#  'vorhaben dabei ist' 'dominieren die negativen' 'positive bzw nicht'
#  'nicht positive bzw' 'normalfall das was'
#  'nachhaltigkeitsstufe sehr gute' 'wird die gesamtbewertung'
#  'zurückgehen und nicht' 'deutlich stufe das'
#  'negativen ergebnisse deutlich' 'der fünf einzelkriterien'
#  'kennzeichnen ein erfolgreiches' 'negativen ergebnisse stufe'
#  'erreichen wird nachhaltigkeitsstufe'
#  'die entwicklungspolitische wirksamkeit'
#  'erwarten kann nachhaltigkeitsstufe' 'trotz einiger positiver'
#  'wird nachhaltigkeitsstufe nicht' 'bleiben normalfall das'
#  'ergebnisse stufe nicht' 'nicht ausreichend eingeschätzt'
#  'effizienz übergeordnete entwicklungspolitische'
#  'positiver teilergebnisse dominieren' 'teilergebnisse dominieren die'
#  'deutlich positiv bleiben' 'bewertet nachhaltigkeitsstufe sehr'
#  'den erwartungen entsprechendes' 'vierstufigen skala bewertet'
#  'sehr gute nachhaltigkeit' 'die bisher positiv'
#  'skala bewertet nachhaltigkeitsstufe' 'ein nicht erfolgreiches'
#  'insgesamt deutlich positiv' 'eingestuft werden kann'
#  'wirksamkeit erreichen wird' 'im vergleich zu'
#  'zunehmen nachhaltigkeitsstufe gute' 'sechsstufige skala verwandt'
#  'sogar zunehmen nachhaltigkeitsstufe' 'positiver ergebnisse die'
#  'erfolgreich eingestuft werden' 'erwartungen entsprechendes ergebnis'
#  'trotz erkennbarer positiver' 'oecd dac kriterien'
#  'der gesamtbewertung kennzeichnen' 'hoher wahrscheinlichkeit gravierend'
#  'gravierend zurückgehen und' 'erläuterungen zur methodik'
#  'evaluierungszeitpunkt nicht ausreichend' 'zufrieden stellendes ergebnis']
#
# Frequency of Most Used Words:
# [4.76760563 4.63732394 3.70774648 2.86619718 2.73943662 2.73943662
#  2.58450704 2.51760563 2.46830986 2.41549296 2.39788732 2.33802817
#  2.05985915 2.04225352 1.84507042 1.73591549 1.72887324 1.71126761
#  1.68309859 1.67957746 1.59507042 1.52112676 1.51408451 1.50704225
#  1.49295775 1.40492958 1.1971831  1.17605634 1.16549296 1.07042254
#  1.0528169  1.0528169  1.04929577 1.03873239 1.03521127 1.00352113
#  0.98239437 0.97183099 0.96830986 0.96478873 0.96478873 0.96126761
#  0.96126761 0.95774648 0.95422535 0.95422535 0.95422535 0.9471831
#  0.9471831  0.94366197 0.94366197 0.94366197 0.94366197 0.93661972
#  0.93661972 0.93309859 0.93309859 0.92957746 0.92957746 0.92605634
#  0.92605634 0.92605634 0.92253521 0.92253521 0.91549296 0.91549296
#  0.91549296 0.91197183 0.91197183 0.91197183 0.9084507  0.9084507
#  0.9084507  0.9084507  0.9084507  0.9084507  0.9084507  0.90492958
#  0.90492958 0.90492958 0.90492958 0.90492958 0.90492958 0.90492958
#  0.90492958 0.90492958 0.90140845 0.90140845 0.90140845 0.90140845
#  0.90140845 0.90140845 0.89788732 0.89788732 0.89788732 0.89788732
#  0.8943662  0.8943662  0.8943662  0.8943662  0.89084507 0.89084507
#  0.88732394 0.88732394 0.88732394 0.88732394 0.88732394 0.88380282
#  0.88380282 0.88028169 0.88028169 0.88028169 0.88028169 0.88028169
#  0.87676056 0.87676056 0.87323944 0.87323944 0.87323944 0.87323944
#  0.86971831 0.86971831 0.86971831 0.86971831 0.86971831 0.86971831
#  0.86619718 0.86619718 0.86619718 0.86267606 0.86267606 0.86267606
#  0.86267606 0.86267606 0.86267606 0.85915493 0.85915493 0.8556338
#  0.8556338  0.8556338  0.8556338  0.8556338  0.85211268 0.85211268
#  0.85211268 0.85211268 0.84859155 0.84859155 0.84507042 0.84507042
#  0.84507042 0.8415493  0.8415493  0.83802817 0.83802817 0.83802817
#  0.83802817 0.83450704 0.83450704 0.83450704 0.83098592 0.83098592
#  0.83098592 0.83098592 0.83098592 0.83098592 0.82746479 0.82746479
#  0.82394366 0.82394366 0.82394366 0.82042254 0.82042254 0.82042254
#  0.82042254 0.82042254 0.82042254 0.82042254 0.81690141 0.81690141
#  0.81690141 0.81690141 0.81338028 0.81338028 0.81338028 0.81338028
#  0.81338028 0.80985915 0.80985915 0.8028169  0.8028169  0.8028169
#  0.8028169  0.8028169  0.8028169  0.8028169  0.79929577 0.79577465
#  0.79577465 0.79577465 0.79225352 0.79225352 0.79225352 0.78873239
#  0.78873239 0.78873239 0.78873239 0.78873239 0.78521127 0.78169014
#  0.78169014 0.78169014 0.78169014 0.77816901 0.77816901 0.77464789
#  0.77464789 0.77464789 0.77112676 0.77112676 0.76760563 0.76408451
#  0.76056338 0.76056338 0.76056338 0.75704225 0.75704225 0.75352113
#  0.75352113 0.75       0.75       0.75       0.75       0.75
#  0.74647887 0.74295775 0.74295775 0.73943662 0.73943662 0.73239437
#  0.73239437 0.72887324 0.72535211 0.72535211 0.72535211 0.71830986
#  0.71830986 0.71478873 0.71478873 0.71478873]

# %% [markdown]
# ## Rating-specific results
# **Features:**
#
# Rating 1/2:
# - deutlich, gut, erreicht, erfolgreich, verbesserungen, erfüllt, umsetzung, zutreffend, verbesserung der, beitrag zur, mit hoher wahrscheinlichkeit, deutlich über den
#
# Rating 3/4:
# - gute, teilweise, allerdings, positiv, positive, positiver, verbesserung der, wirksamkeit des vorhabens, bisher positive, positive entwicklungspolitische wirksamkeit, unter den erwartungen, die negativen ergebnisse, dominieren die
#
# Rating 5/6:
# - unzureichend, geringen, mängel, nicht erfolgreich, nicht erfolgreiche, überwiegend nicht, auch nicht, überwiegend nicht erfolgreich, vorhaben ist nutzlos

# %%
# Existing text count lists initialization
texts = list(agg_data["pdf_text"])

# Initialize lists for each phrase
count_deutlich = []
count_gut = []
count_erreicht = []
count_erfolgreich = []
count_verbesserungen = []
count_erfuellt = []
count_umsetzung = []
count_zutreffend = []
count_verbesserung_der = []
count_beitrag_zur = []
count_mit_hoher_wahrscheinlichkeit = []
count_deutlich_ueber_den = []
count_gute = []
count_teilweise = []
count_allerdings = []
count_positiv = []
count_positive = []
count_positiver = []
count_wirksamkeit_des_vorhabens = []
count_bisher_positive = []
count_positive_entwicklungspolitische_wirksamkeit = []
count_unter_den_erwartungen = []
count_die_negativen_ergebnisse = []
count_dominieren_die = []
count_unzureichend = []
count_geringen = []
count_maengel = []
count_nicht_erfolgreich = []
count_nicht_erfolgreiche = []
count_ueberwiegend_nicht = []
count_auch_nicht = []
count_ueberwiegend_nicht_erfolgreich = []
count_vorhaben_ist_nutzlos = []

# Iterate through the texts to count occurrences of each phrase
for text in texts:
    count_deutlich.append(text.count("deutlich"))
    count_gut.append(text.count("gut"))
    count_erreicht.append(text.count("erreicht"))
    count_erfolgreich.append(text.count("erfolgreich"))
    count_verbesserungen.append(text.count("verbesserungen"))
    count_erfuellt.append(text.count("erfüllt"))
    count_umsetzung.append(text.count("umsetzung"))
    count_zutreffend.append(text.count("zutreffend"))
    count_verbesserung_der.append(text.count("verbesserung der"))
    count_beitrag_zur.append(text.count("beitrag zur"))
    count_mit_hoher_wahrscheinlichkeit.append(text.count("mit hoher wahrscheinlichkeit"))
    count_deutlich_ueber_den.append(text.count("deutlich über den"))
    count_gute.append(text.count("gute"))
    count_teilweise.append(text.count("teilweise"))
    count_allerdings.append(text.count("allerdings"))
    count_positiv.append(text.count("positiv"))
    count_positive.append(text.count("positive"))
    count_positiver.append(text.count("positiver"))
    count_wirksamkeit_des_vorhabens.append(text.count("wirksamkeit des vorhabens"))
    count_bisher_positive.append(text.count("bisher positive"))
    count_positive_entwicklungspolitische_wirksamkeit.append(text.count("positive entwicklungspolitische wirksamkeit"))
    count_unter_den_erwartungen.append(text.count("unter den erwartungen"))
    count_die_negativen_ergebnisse.append(text.count("die negativen ergebnisse"))
    count_dominieren_die.append(text.count("dominieren die"))
    count_unzureichend.append(text.count("unzureichend"))
    count_geringen.append(text.count("geringen"))
    count_maengel.append(text.count("mängel"))
    count_nicht_erfolgreich.append(text.count("nicht erfolgreich"))
    count_nicht_erfolgreiche.append(text.count("nicht erfolgreiche"))
    count_ueberwiegend_nicht.append(text.count("überwiegend nicht"))
    count_auch_nicht.append(text.count("auch nicht"))
    count_ueberwiegend_nicht_erfolgreich.append(text.count("überwiegend nicht erfolgreich"))
    count_vorhaben_ist_nutzlos.append(text.count("vorhaben ist nutzlos"))

# Add the count lists as new columns to the DataFrame
agg_data['count_deutlich'] = count_deutlich
agg_data['count_gut'] = count_gut
agg_data['count_erreicht'] = count_erreicht
agg_data['count_erfolgreich'] = count_erfolgreich
agg_data['count_verbesserungen'] = count_verbesserungen
agg_data['count_erfuellt'] = count_erfuellt
agg_data['count_umsetzung'] = count_umsetzung
agg_data['count_zutreffend'] = count_zutreffend
agg_data['count_verbesserung_der'] = count_verbesserung_der
agg_data['count_beitrag_zur'] = count_beitrag_zur
agg_data['count_mit_hoher_wahrscheinlichkeit'] = count_mit_hoher_wahrscheinlichkeit
agg_data['count_deutlich_ueber_den'] = count_deutlich_ueber_den
agg_data['count_gute'] = count_gute
agg_data['count_teilweise'] = count_teilweise
agg_data['count_allerdings'] = count_allerdings
agg_data['count_positiv'] = count_positiv
agg_data['count_positive'] = count_positive
agg_data['count_positiver'] = count_positiver
agg_data['count_wirksamkeit_des_vorhabens'] = count_wirksamkeit_des_vorhabens
agg_data['count_bisher_positive'] = count_bisher_positive
agg_data['count_positive_entwicklungspolitische_wirksamkeit'] = count_positive_entwicklungspolitische_wirksamkeit
agg_data['count_unter_den_erwartungen'] = count_unter_den_erwartungen
agg_data['count_die_negativen_ergebnisse'] = count_die_negativen_ergebnisse
agg_data['count_dominieren_die'] = count_dominieren_die
agg_data['count_unzureichend'] = count_unzureichend
agg_data['count_geringen'] = count_geringen
agg_data['count_maengel'] = count_maengel
agg_data['count_nicht_erfolgreich'] = count_nicht_erfolgreich
agg_data['count_nicht_erfolgreiche'] = count_nicht_erfolgreiche
agg_data['count_ueberwiegend_nicht'] = count_ueberwiegend_nicht
agg_data['count_auch_nicht'] = count_auch_nicht
agg_data['count_ueberwiegend_nicht_erfolgreich'] = count_ueberwiegend_nicht_erfolgreich
agg_data['count_vorhaben_ist_nutzlos'] = count_vorhaben_ist_nutzlos

agg_data.head()
# Out:
#                               pdf  \
# 0    %C3%84gypten_Qena_2022_D.pdf
# 1  %C3%84gypten_Umwelt_2022_D.pdf
# 2  %C3%84thiopien_Gavi_2022_D.pdf
# 3           Afrika_TCX_2012_D.pdf
# 4       Albanien_Elbasan_2011.pdf
#
#                                         project_name  multiple_phases  \
# 0   Kommunale Wasserver- und Abwasserentsorgung Qena                0
# 1  Förderung von Umweltschutzmaßnahmen der privat...                0
# 2  Impfprogrammförderung in Äthiopien in Zusammen...                0
# 3                             Lokalwährungsfonds TCX                0
# 4  Wirtschaftsförderung durch Ausbau kommunaler I...                0
#
#    number_countries  eval_year  number_sectors  number_subsectors  \
# 0                 1       2022               1                  1
# 1                 1       2022               1                  1
# 2                 1       2022               1                  1
# 3                 1       2012               1                  1
# 4                 1       2011               1                  1
#
#    mean_investment  number_funding_source  number_carrier_type  ...  \
# 0       12670000.0                      1                    1  ...
# 1       25780000.0                      1                    1  ...
# 2       10000000.0                      1                    1  ...
# 3       90000000.0                      1                    1  ...
# 4       10600000.0                      1                    1  ...
#
#    count_dominieren_die  count_unzureichend  count_geringen  count_maengel  \
# 0                     2                   4               7              3
# 1                     2                   6               5              1
# 2                     0                   1               0              1
# 3                     2                   1               0              1
# 4                     2                   3               0              1
#
#    count_nicht_erfolgreich  count_nicht_erfolgreiche  \
# 0                        9                         4
# 1                        6                         3
# 2                        3                         1
# 3                        2                         2
# 4                        2                         2
#
#    count_ueberwiegend_nicht count_auch_nicht  \
# 0                         2                1
# 1                         2                1
# 2                         0                2
# 3                         0                1
# 4                         0                2
#
#    count_ueberwiegend_nicht_erfolgreich  count_vorhaben_ist_nutzlos
# 0                                     2                           1
# 1                                     2                           1
# 2                                     0                           0
# 3                                     0                           1
# 4                                     0                           1
#
# [5 rows x 58 columns]

# %%
agg_data.to_csv("agg_data5.csv", index=False)
