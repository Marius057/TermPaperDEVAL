# %% [markdown]
# In this file, we:
#
# - Use the API to extract meta-data for every project
#
# **Result: project_data.csv**

# %%
import requests
import numpy as np

ids = np.arange(1, 1500, 1)

# API Url
base_url = "https://www.kfw-entwicklungsbank.de/kfw-ideal-service/api/projects/detail/DE/highRes/"

# Function to get project details for a given ID
def get_project_details(project_id):
    url = f"{base_url}{project_id}"
    response = requests.get(url)
    if response.status_code == 200:
        try:
            return response.json()
        except ValueError:
            print(f"Failed to decode JSON for ID {project_id}. Response content: {response.content}")
            return None
    else:
        print(f"Failed to retrieve data for ID {project_id}. Status code: {response.status_code}")
        return None

# Function to calculate the percentages of each indicator/status
def calculate_status_percentages(indicators):
    total_goals = len(indicators)
    if total_goals == 0:
        return (0, 0, 0)  # Handle case with no goals

    status_counts = {"erfüllt": 0, "teils erfüllt": 0, "nicht erfüllt": 0}
    for indicator in indicators:
        status = indicator["status"].lower()
        if status in status_counts:
            status_counts[status] += 1

    # Calculate percentages
    percent_fully = status_counts["erfüllt"] / total_goals * 100
    percent_partial = status_counts["teils erfüllt"] / total_goals * 100
    percent_not = status_counts["nicht erfüllt"] / total_goals * 100

    return percent_fully, percent_partial, percent_not


project_name_list = []
country_list = []
year_list = []
sector_list = []
subsector_list = []
investment_list = []
fund_source_list = []
carrier_type_list = []
overall_list = []
relevance_list = []
coherence_list = []
effectivity_list = []
efficiency_list = []
impact_list = []
sustainability_list = []
url_list = []
outcome_fully = []
outcome_partially = []
outcome_not = []

for project_id in ids:
    print(project_id,"out of",ids)
    project_details = get_project_details(project_id)
    if project_details:

        project_name = project_details.get('projectName', 'N/A')
        country = project_details.get('country', 'N/A')
        year = project_details.get('year', 'N/A')
        sector = project_details.get('sector', 'N/A')
        subsector = project_details.get('sector2', 'N/A')
        investment = project_details.get('investment', 'N/A')
        fund_source = project_details.get('sourceOfFounds', 'N/A')
        carrier_type = project_details.get('carrierType', 'N/A')
        rating = project_details.get('rating', {})
        overall = rating.get('overall', 'N/A')
        relevance = rating.get('relevance', 'N/A')
        coherence = rating.get('coherence', 'N/A')
        effectivity = rating.get('effectivity', 'N/A')
        efficiency = rating.get('efficiency', 'N/A')
        impact = rating.get('impact', 'N/A')
        sustainability = rating.get('sustainability', 'N/A')
        url = project_details.get('reportUrl', 'N/A')

        indicators = project_details.get('outcome', {})
        indicators = indicators.get('indicators', [])
        percent_fully, percent_partial, percent_not = calculate_status_percentages(indicators)

        project_name_list.append(project_name)
        country_list.append(country)
        year_list.append(year)
        sector_list.append(sector)
        subsector_list.append(subsector)
        investment_list.append(investment)
        fund_source_list.append(fund_source)
        carrier_type_list.append(carrier_type)
        overall_list.append(overall)
        relevance_list.append(relevance)
        coherence_list.append(coherence)
        effectivity_list.append(effectivity)
        efficiency_list.append(efficiency)
        impact_list.append(impact)
        sustainability_list.append(sustainability)
        url_list.append(url)

        outcome_fully.append(percent_fully)
        outcome_partially.append(percent_partial)
        outcome_not.append(percent_not)
# Out:
# 1 out of [   1    2    3 ... 1497 1498 1499]
# 2 out of [   1    2    3 ... 1497 1498 1499]
# 3 out of [   1    2    3 ... 1497 1498 1499]
# 4 out of [   1    2    3 ... 1497 1498 1499]
# 5 out of [   1    2    3 ... 1497 1498 1499]
# 6 out of [   1    2    3 ... 1497 1498 1499]
# 7 out of [   1    2    3 ... 1497 1498 1499]
# 8 out of [   1    2    3 ... 1497 1498 1499]
# 9 out of [   1    2    3 ... 1497 1498 1499]
# 10 out of [   1    2    3 ... 1497 1498 1499]
# 11 out of [   1    2    3 ... 1497 1498 1499]
# 12 out of [   1    2    3 ... 1497 1498 1499]
# 13 out of [   1    2    3 ... 1497 1498 1499]
# 14 out of [   1    2    3 ... 1497 1498 1499]
# 15 out of [   1    2    3 ... 1497 1498 1499]
# 16 out of [   1    2    3 ... 1497 1498 1499]
# 17 out of [   1    2    3 ... 1497 1498 1499]
# 18 out of [   1    2    3 ... 1497 1498 1499]
# 19 out of [   1    2    3 ... 1497 1498 1499]
# 20 out of [   1    2    3 ... 1497 1498 1499]
# 21 out of [   1    2    3 ... 1497 1498 1499]
# 22 out of [   1    2    3 ... 1497 1498 1499]
# 23 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 23. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409493763713<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 24 out of [   1    2    3 ... 1497 1498 1499]
# 25 out of [   1    2    3 ... 1497 1498 1499]
# 26 out of [   1    2    3 ... 1497 1498 1499]
# 27 out of [   1    2    3 ... 1497 1498 1499]
# 28 out of [   1    2    3 ... 1497 1498 1499]
# 29 out of [   1    2    3 ... 1497 1498 1499]
# 30 out of [   1    2    3 ... 1497 1498 1499]
# 31 out of [   1    2    3 ... 1497 1498 1499]
# 32 out of [   1    2    3 ... 1497 1498 1499]
# 33 out of [   1    2    3 ... 1497 1498 1499]
# 34 out of [   1    2    3 ... 1497 1498 1499]
# 35 out of [   1    2    3 ... 1497 1498 1499]
# 36 out of [   1    2    3 ... 1497 1498 1499]
# 37 out of [   1    2    3 ... 1497 1498 1499]
# 38 out of [   1    2    3 ... 1497 1498 1499]
# 39 out of [   1    2    3 ... 1497 1498 1499]
# 40 out of [   1    2    3 ... 1497 1498 1499]
# 41 out of [   1    2    3 ... 1497 1498 1499]
# 42 out of [   1    2    3 ... 1497 1498 1499]
# 43 out of [   1    2    3 ... 1497 1498 1499]
# 44 out of [   1    2    3 ... 1497 1498 1499]
# 45 out of [   1    2    3 ... 1497 1498 1499]
# 46 out of [   1    2    3 ... 1497 1498 1499]
# 47 out of [   1    2    3 ... 1497 1498 1499]
# 48 out of [   1    2    3 ... 1497 1498 1499]
# 49 out of [   1    2    3 ... 1497 1498 1499]
# 50 out of [   1    2    3 ... 1497 1498 1499]
# 51 out of [   1    2    3 ... 1497 1498 1499]
# 52 out of [   1    2    3 ... 1497 1498 1499]
# 53 out of [   1    2    3 ... 1497 1498 1499]
# 54 out of [   1    2    3 ... 1497 1498 1499]
# 55 out of [   1    2    3 ... 1497 1498 1499]
# 56 out of [   1    2    3 ... 1497 1498 1499]
# 57 out of [   1    2    3 ... 1497 1498 1499]
# 58 out of [   1    2    3 ... 1497 1498 1499]
# 59 out of [   1    2    3 ... 1497 1498 1499]
# 60 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 60. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409485956357<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 61 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 61. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409485956469<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 62 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 62. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516771236<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 63 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 63. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409485956869<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 64 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 64. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409485956933<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 65 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 65. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522374838<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 66 out of [   1    2    3 ... 1497 1498 1499]
# 67 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 67. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516771972<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 68 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 68. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470108743<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 69 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 69. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516772580<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 70 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 70. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522375366<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 71 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 71. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409485957301<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 72 out of [   1    2    3 ... 1497 1498 1499]
# 73 out of [   1    2    3 ... 1497 1498 1499]
# 74 out of [   1    2    3 ... 1497 1498 1499]
# 75 out of [   1    2    3 ... 1497 1498 1499]
# 76 out of [   1    2    3 ... 1497 1498 1499]
# 77 out of [   1    2    3 ... 1497 1498 1499]
# 78 out of [   1    2    3 ... 1497 1498 1499]
# 79 out of [   1    2    3 ... 1497 1498 1499]
# 80 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 80. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522376710<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 81 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 81. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409485957925<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 82 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 82. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522376854<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 83 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 83. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409485958213<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 84 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 84. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409485958405<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 85 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 85. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516774372<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 86 out of [   1    2    3 ... 1497 1498 1499]
# 87 out of [   1    2    3 ... 1497 1498 1499]
# 88 out of [   1    2    3 ... 1497 1498 1499]
# 89 out of [   1    2    3 ... 1497 1498 1499]
# 90 out of [   1    2    3 ... 1497 1498 1499]
# 91 out of [   1    2    3 ... 1497 1498 1499]
# 92 out of [   1    2    3 ... 1497 1498 1499]
# 93 out of [   1    2    3 ... 1497 1498 1499]
# 94 out of [   1    2    3 ... 1497 1498 1499]
# 95 out of [   1    2    3 ... 1497 1498 1499]
# 96 out of [   1    2    3 ... 1497 1498 1499]
# 97 out of [   1    2    3 ... 1497 1498 1499]
# 98 out of [   1    2    3 ... 1497 1498 1499]
# 99 out of [   1    2    3 ... 1497 1498 1499]
# 100 out of [   1    2    3 ... 1497 1498 1499]
# 101 out of [   1    2    3 ... 1497 1498 1499]
# 102 out of [   1    2    3 ... 1497 1498 1499]
# 103 out of [   1    2    3 ... 1497 1498 1499]
# 104 out of [   1    2    3 ... 1497 1498 1499]
# 105 out of [   1    2    3 ... 1497 1498 1499]
# 106 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 106. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409481872978<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 107 out of [   1    2    3 ... 1497 1498 1499]
# 108 out of [   1    2    3 ... 1497 1498 1499]
# 109 out of [   1    2    3 ... 1497 1498 1499]
# 110 out of [   1    2    3 ... 1497 1498 1499]
# 111 out of [   1    2    3 ... 1497 1498 1499]
# 112 out of [   1    2    3 ... 1497 1498 1499]
# 113 out of [   1    2    3 ... 1497 1498 1499]
# 114 out of [   1    2    3 ... 1497 1498 1499]
# 115 out of [   1    2    3 ... 1497 1498 1499]
# 116 out of [   1    2    3 ... 1497 1498 1499]
# 117 out of [   1    2    3 ... 1497 1498 1499]
# 118 out of [   1    2    3 ... 1497 1498 1499]
# 119 out of [   1    2    3 ... 1497 1498 1499]
# 120 out of [   1    2    3 ... 1497 1498 1499]
# 121 out of [   1    2    3 ... 1497 1498 1499]
# 122 out of [   1    2    3 ... 1497 1498 1499]
# 123 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 123. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409481874642<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 124 out of [   1    2    3 ... 1497 1498 1499]
# 125 out of [   1    2    3 ... 1497 1498 1499]
# 126 out of [   1    2    3 ... 1497 1498 1499]
# 127 out of [   1    2    3 ... 1497 1498 1499]
# 128 out of [   1    2    3 ... 1497 1498 1499]
# 129 out of [   1    2    3 ... 1497 1498 1499]
# 130 out of [   1    2    3 ... 1497 1498 1499]
# 131 out of [   1    2    3 ... 1497 1498 1499]
# 132 out of [   1    2    3 ... 1497 1498 1499]
# 133 out of [   1    2    3 ... 1497 1498 1499]
# 134 out of [   1    2    3 ... 1497 1498 1499]
# 135 out of [   1    2    3 ... 1497 1498 1499]
# 136 out of [   1    2    3 ... 1497 1498 1499]
# 137 out of [   1    2    3 ... 1497 1498 1499]
# 138 out of [   1    2    3 ... 1497 1498 1499]
# 139 out of [   1    2    3 ... 1497 1498 1499]
# 140 out of [   1    2    3 ... 1497 1498 1499]
# 141 out of [   1    2    3 ... 1497 1498 1499]
# 142 out of [   1    2    3 ... 1497 1498 1499]
# 143 out of [   1    2    3 ... 1497 1498 1499]
# 144 out of [   1    2    3 ... 1497 1498 1499]
# 145 out of [   1    2    3 ... 1497 1498 1499]
# 146 out of [   1    2    3 ... 1497 1498 1499]
# 147 out of [   1    2    3 ... 1497 1498 1499]
# 148 out of [   1    2    3 ... 1497 1498 1499]
# 149 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 149. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409493777649<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 150 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 150. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409493777825<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 151 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 151. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470117991<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 152 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 152. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470118087<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 153 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 153. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470118183<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 154 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 154. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470118503<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 155 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 155. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516781236<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 156 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 156. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409485965493<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 157 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 157. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409485965509<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 158 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 158. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470118743<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 159 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 159. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470118967<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 160 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 160. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522383926<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 161 out of [   1    2    3 ... 1497 1498 1499]
# 162 out of [   1    2    3 ... 1497 1498 1499]
# 163 out of [   1    2    3 ... 1497 1498 1499]
# 164 out of [   1    2    3 ... 1497 1498 1499]
# 165 out of [   1    2    3 ... 1497 1498 1499]
# 166 out of [   1    2    3 ... 1497 1498 1499]
# 167 out of [   1    2    3 ... 1497 1498 1499]
# 168 out of [   1    2    3 ... 1497 1498 1499]
# 169 out of [   1    2    3 ... 1497 1498 1499]
# 170 out of [   1    2    3 ... 1497 1498 1499]
# 171 out of [   1    2    3 ... 1497 1498 1499]
# 172 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 172. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470119655<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 173 out of [   1    2    3 ... 1497 1498 1499]
# 174 out of [   1    2    3 ... 1497 1498 1499]
# 175 out of [   1    2    3 ... 1497 1498 1499]
# 176 out of [   1    2    3 ... 1497 1498 1499]
# 177 out of [   1    2    3 ... 1497 1498 1499]
# 178 out of [   1    2    3 ... 1497 1498 1499]
# 179 out of [   1    2    3 ... 1497 1498 1499]
# 180 out of [   1    2    3 ... 1497 1498 1499]
# 181 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 181. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522385622<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 182 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 182. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522385638<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 183 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 183. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522385670<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 184 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 184. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522385830<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 185 out of [   1    2    3 ... 1497 1498 1499]
# 186 out of [   1    2    3 ... 1497 1498 1499]
# 187 out of [   1    2    3 ... 1497 1498 1499]
# 188 out of [   1    2    3 ... 1497 1498 1499]
# 189 out of [   1    2    3 ... 1497 1498 1499]
# 190 out of [   1    2    3 ... 1497 1498 1499]
# 191 out of [   1    2    3 ... 1497 1498 1499]
# 192 out of [   1    2    3 ... 1497 1498 1499]
# 193 out of [   1    2    3 ... 1497 1498 1499]
# 194 out of [   1    2    3 ... 1497 1498 1499]
# 195 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 195. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516784404<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 196 out of [   1    2    3 ... 1497 1498 1499]
# 197 out of [   1    2    3 ... 1497 1498 1499]
# 198 out of [   1    2    3 ... 1497 1498 1499]
# 199 out of [   1    2    3 ... 1497 1498 1499]
# 200 out of [   1    2    3 ... 1497 1498 1499]
# 201 out of [   1    2    3 ... 1497 1498 1499]
# 202 out of [   1    2    3 ... 1497 1498 1499]
# 203 out of [   1    2    3 ... 1497 1498 1499]
# 204 out of [   1    2    3 ... 1497 1498 1499]
# 205 out of [   1    2    3 ... 1497 1498 1499]
# 206 out of [   1    2    3 ... 1497 1498 1499]
# 207 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 207. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409481882258<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 208 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 208. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409528079779<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 209 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 209. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409493781697<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 210 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 210. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409493781825<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 211 out of [   1    2    3 ... 1497 1498 1499]
# 212 out of [   1    2    3 ... 1497 1498 1499]
# 213 out of [   1    2    3 ... 1497 1498 1499]
# 214 out of [   1    2    3 ... 1497 1498 1499]
# 215 out of [   1    2    3 ... 1497 1498 1499]
# 216 out of [   1    2    3 ... 1497 1498 1499]
# 217 out of [   1    2    3 ... 1497 1498 1499]
# 218 out of [   1    2    3 ... 1497 1498 1499]
# 219 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 219. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409498470816<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 220 out of [   1    2    3 ... 1497 1498 1499]
# 221 out of [   1    2    3 ... 1497 1498 1499]
# 222 out of [   1    2    3 ... 1497 1498 1499]
# 223 out of [   1    2    3 ... 1497 1498 1499]
# 224 out of [   1    2    3 ... 1497 1498 1499]
# 225 out of [   1    2    3 ... 1497 1498 1499]
# 226 out of [   1    2    3 ... 1497 1498 1499]
# 227 out of [   1    2    3 ... 1497 1498 1499]
# 228 out of [   1    2    3 ... 1497 1498 1499]
# 229 out of [   1    2    3 ... 1497 1498 1499]
# 230 out of [   1    2    3 ... 1497 1498 1499]
# 231 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 231. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409481883538<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 232 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 232. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409498471648<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 233 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 233. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409498471696<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 234 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 234. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409528081843<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 235 out of [   1    2    3 ... 1497 1498 1499]
# 236 out of [   1    2    3 ... 1497 1498 1499]
# 237 out of [   1    2    3 ... 1497 1498 1499]
# 238 out of [   1    2    3 ... 1497 1498 1499]
# 239 out of [   1    2    3 ... 1497 1498 1499]
# 240 out of [   1    2    3 ... 1497 1498 1499]
# 241 out of [   1    2    3 ... 1497 1498 1499]
# 242 out of [   1    2    3 ... 1497 1498 1499]
# 243 out of [   1    2    3 ... 1497 1498 1499]
# 244 out of [   1    2    3 ... 1497 1498 1499]
# 245 out of [   1    2    3 ... 1497 1498 1499]
# 246 out of [   1    2    3 ... 1497 1498 1499]
# 247 out of [   1    2    3 ... 1497 1498 1499]
# 248 out of [   1    2    3 ... 1497 1498 1499]
# 249 out of [   1    2    3 ... 1497 1498 1499]
# 250 out of [   1    2    3 ... 1497 1498 1499]
# 251 out of [   1    2    3 ... 1497 1498 1499]
# 252 out of [   1    2    3 ... 1497 1498 1499]
# 253 out of [   1    2    3 ... 1497 1498 1499]
# 254 out of [   1    2    3 ... 1497 1498 1499]
# 255 out of [   1    2    3 ... 1497 1498 1499]
# 256 out of [   1    2    3 ... 1497 1498 1499]
# 257 out of [   1    2    3 ... 1497 1498 1499]
# 258 out of [   1    2    3 ... 1497 1498 1499]
# 259 out of [   1    2    3 ... 1497 1498 1499]
# 260 out of [   1    2    3 ... 1497 1498 1499]
# 261 out of [   1    2    3 ... 1497 1498 1499]
# 262 out of [   1    2    3 ... 1497 1498 1499]
# 263 out of [   1    2    3 ... 1497 1498 1499]
# 264 out of [   1    2    3 ... 1497 1498 1499]
# 265 out of [   1    2    3 ... 1497 1498 1499]
# 266 out of [   1    2    3 ... 1497 1498 1499]
# 267 out of [   1    2    3 ... 1497 1498 1499]
# 268 out of [   1    2    3 ... 1497 1498 1499]
# 269 out of [   1    2    3 ... 1497 1498 1499]
# 270 out of [   1    2    3 ... 1497 1498 1499]
# 271 out of [   1    2    3 ... 1497 1498 1499]
# 272 out of [   1    2    3 ... 1497 1498 1499]
# 273 out of [   1    2    3 ... 1497 1498 1499]
# 274 out of [   1    2    3 ... 1497 1498 1499]
# 275 out of [   1    2    3 ... 1497 1498 1499]
# 276 out of [   1    2    3 ... 1497 1498 1499]
# 277 out of [   1    2    3 ... 1497 1498 1499]
# 278 out of [   1    2    3 ... 1497 1498 1499]
# 279 out of [   1    2    3 ... 1497 1498 1499]
# 280 out of [   1    2    3 ... 1497 1498 1499]
# 281 out of [   1    2    3 ... 1497 1498 1499]
# 282 out of [   1    2    3 ... 1497 1498 1499]
# 283 out of [   1    2    3 ... 1497 1498 1499]
# 284 out of [   1    2    3 ... 1497 1498 1499]
# 285 out of [   1    2    3 ... 1497 1498 1499]
# 286 out of [   1    2    3 ... 1497 1498 1499]
# 287 out of [   1    2    3 ... 1497 1498 1499]
# 288 out of [   1    2    3 ... 1497 1498 1499]
# 289 out of [   1    2    3 ... 1497 1498 1499]
# 290 out of [   1    2    3 ... 1497 1498 1499]
# 291 out of [   1    2    3 ... 1497 1498 1499]
# 292 out of [   1    2    3 ... 1497 1498 1499]
# 293 out of [   1    2    3 ... 1497 1498 1499]
# 294 out of [   1    2    3 ... 1497 1498 1499]
# 295 out of [   1    2    3 ... 1497 1498 1499]
# 296 out of [   1    2    3 ... 1497 1498 1499]
# 297 out of [   1    2    3 ... 1497 1498 1499]
# 298 out of [   1    2    3 ... 1497 1498 1499]
# 299 out of [   1    2    3 ... 1497 1498 1499]
# 300 out of [   1    2    3 ... 1497 1498 1499]
# 301 out of [   1    2    3 ... 1497 1498 1499]
# 302 out of [   1    2    3 ... 1497 1498 1499]
# 303 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 303. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522396310<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 304 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 304. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470131831<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 305 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 305. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516794724<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 306 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 306. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516794756<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 307 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 307. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470132039<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 308 out of [   1    2    3 ... 1497 1498 1499]
# 309 out of [   1    2    3 ... 1497 1498 1499]
# 310 out of [   1    2    3 ... 1497 1498 1499]
# 311 out of [   1    2    3 ... 1497 1498 1499]
# 312 out of [   1    2    3 ... 1497 1498 1499]
# 313 out of [   1    2    3 ... 1497 1498 1499]
# 314 out of [   1    2    3 ... 1497 1498 1499]
# 315 out of [   1    2    3 ... 1497 1498 1499]
# 316 out of [   1    2    3 ... 1497 1498 1499]
# 317 out of [   1    2    3 ... 1497 1498 1499]
# 318 out of [   1    2    3 ... 1497 1498 1499]
# 319 out of [   1    2    3 ... 1497 1498 1499]
# 320 out of [   1    2    3 ... 1497 1498 1499]
# 321 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 321. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409498478640<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 322 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 322. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409528090515<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 323 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 323. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409528090579<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 324 out of [   1    2    3 ... 1497 1498 1499]
# 325 out of [   1    2    3 ... 1497 1498 1499]
# 326 out of [   1    2    3 ... 1497 1498 1499]
# 327 out of [   1    2    3 ... 1497 1498 1499]
# 328 out of [   1    2    3 ... 1497 1498 1499]
# 329 out of [   1    2    3 ... 1497 1498 1499]
# 330 out of [   1    2    3 ... 1497 1498 1499]
# 331 out of [   1    2    3 ... 1497 1498 1499]
# 332 out of [   1    2    3 ... 1497 1498 1499]
# 333 out of [   1    2    3 ... 1497 1498 1499]
# 334 out of [   1    2    3 ... 1497 1498 1499]
# 335 out of [   1    2    3 ... 1497 1498 1499]
# 336 out of [   1    2    3 ... 1497 1498 1499]
# 337 out of [   1    2    3 ... 1497 1498 1499]
# 338 out of [   1    2    3 ... 1497 1498 1499]
# 339 out of [   1    2    3 ... 1497 1498 1499]
# 340 out of [   1    2    3 ... 1497 1498 1499]
# 341 out of [   1    2    3 ... 1497 1498 1499]
# 342 out of [   1    2    3 ... 1497 1498 1499]
# 343 out of [   1    2    3 ... 1497 1498 1499]
# 344 out of [   1    2    3 ... 1497 1498 1499]
# 345 out of [   1    2    3 ... 1497 1498 1499]
# 346 out of [   1    2    3 ... 1497 1498 1499]
# 347 out of [   1    2    3 ... 1497 1498 1499]
# 348 out of [   1    2    3 ... 1497 1498 1499]
# 349 out of [   1    2    3 ... 1497 1498 1499]
# 350 out of [   1    2    3 ... 1497 1498 1499]
# 351 out of [   1    2    3 ... 1497 1498 1499]
# 352 out of [   1    2    3 ... 1497 1498 1499]
# 353 out of [   1    2    3 ... 1497 1498 1499]
# 354 out of [   1    2    3 ... 1497 1498 1499]
# 355 out of [   1    2    3 ... 1497 1498 1499]
# 356 out of [   1    2    3 ... 1497 1498 1499]
# 357 out of [   1    2    3 ... 1497 1498 1499]
# 358 out of [   1    2    3 ... 1497 1498 1499]
# 359 out of [   1    2    3 ... 1497 1498 1499]
# 360 out of [   1    2    3 ... 1497 1498 1499]
# 361 out of [   1    2    3 ... 1497 1498 1499]
# 362 out of [   1    2    3 ... 1497 1498 1499]
# 363 out of [   1    2    3 ... 1497 1498 1499]
# 364 out of [   1    2    3 ... 1497 1498 1499]
# 365 out of [   1    2    3 ... 1497 1498 1499]
# 366 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 366. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409481894578<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 367 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 367. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409498481856<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 368 out of [   1    2    3 ... 1497 1498 1499]
# 369 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 369. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409498482128<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 370 out of [   1    2    3 ... 1497 1498 1499]
# 371 out of [   1    2    3 ... 1497 1498 1499]
# 372 out of [   1    2    3 ... 1497 1498 1499]
# 373 out of [   1    2    3 ... 1497 1498 1499]
# 374 out of [   1    2    3 ... 1497 1498 1499]
# 375 out of [   1    2    3 ... 1497 1498 1499]
# 376 out of [   1    2    3 ... 1497 1498 1499]
# 377 out of [   1    2    3 ... 1497 1498 1499]
# 378 out of [   1    2    3 ... 1497 1498 1499]
# 379 out of [   1    2    3 ... 1497 1498 1499]
# 380 out of [   1    2    3 ... 1497 1498 1499]
# 381 out of [   1    2    3 ... 1497 1498 1499]
# 382 out of [   1    2    3 ... 1497 1498 1499]
# 383 out of [   1    2    3 ... 1497 1498 1499]
# 384 out of [   1    2    3 ... 1497 1498 1499]
# 385 out of [   1    2    3 ... 1497 1498 1499]
# 386 out of [   1    2    3 ... 1497 1498 1499]
# 387 out of [   1    2    3 ... 1497 1498 1499]
# 388 out of [   1    2    3 ... 1497 1498 1499]
# 389 out of [   1    2    3 ... 1497 1498 1499]
# 390 out of [   1    2    3 ... 1497 1498 1499]
# 391 out of [   1    2    3 ... 1497 1498 1499]
# 392 out of [   1    2    3 ... 1497 1498 1499]
# 393 out of [   1    2    3 ... 1497 1498 1499]
# 394 out of [   1    2    3 ... 1497 1498 1499]
# 395 out of [   1    2    3 ... 1497 1498 1499]
# 396 out of [   1    2    3 ... 1497 1498 1499]
# 397 out of [   1    2    3 ... 1497 1498 1499]
# 398 out of [   1    2    3 ... 1497 1498 1499]
# 399 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 399. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516802308<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 400 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 400. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516802420<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 401 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 401. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409485986165<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 402 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 402. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516802692<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 403 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 403. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470139047<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 404 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 404. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522405158<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 405 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 405. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409485986581<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 406 out of [   1    2    3 ... 1497 1498 1499]
# 407 out of [   1    2    3 ... 1497 1498 1499]
# 408 out of [   1    2    3 ... 1497 1498 1499]
# 409 out of [   1    2    3 ... 1497 1498 1499]
# 410 out of [   1    2    3 ... 1497 1498 1499]
# 411 out of [   1    2    3 ... 1497 1498 1499]
# 412 out of [   1    2    3 ... 1497 1498 1499]
# 413 out of [   1    2    3 ... 1497 1498 1499]
# 414 out of [   1    2    3 ... 1497 1498 1499]
# 415 out of [   1    2    3 ... 1497 1498 1499]
# 416 out of [   1    2    3 ... 1497 1498 1499]
# 417 out of [   1    2    3 ... 1497 1498 1499]
# 418 out of [   1    2    3 ... 1497 1498 1499]
# 419 out of [   1    2    3 ... 1497 1498 1499]
# 420 out of [   1    2    3 ... 1497 1498 1499]
# 421 out of [   1    2    3 ... 1497 1498 1499]
# 422 out of [   1    2    3 ... 1497 1498 1499]
# 423 out of [   1    2    3 ... 1497 1498 1499]
# 424 out of [   1    2    3 ... 1497 1498 1499]
# 425 out of [   1    2    3 ... 1497 1498 1499]
# 426 out of [   1    2    3 ... 1497 1498 1499]
# 427 out of [   1    2    3 ... 1497 1498 1499]
# 428 out of [   1    2    3 ... 1497 1498 1499]
# 429 out of [   1    2    3 ... 1497 1498 1499]
# 430 out of [   1    2    3 ... 1497 1498 1499]
# 431 out of [   1    2    3 ... 1497 1498 1499]
# 432 out of [   1    2    3 ... 1497 1498 1499]
# 433 out of [   1    2    3 ... 1497 1498 1499]
# 434 out of [   1    2    3 ... 1497 1498 1499]
# 435 out of [   1    2    3 ... 1497 1498 1499]
# 436 out of [   1    2    3 ... 1497 1498 1499]
# 437 out of [   1    2    3 ... 1497 1498 1499]
# 438 out of [   1    2    3 ... 1497 1498 1499]
# 439 out of [   1    2    3 ... 1497 1498 1499]
# 440 out of [   1    2    3 ... 1497 1498 1499]
# 441 out of [   1    2    3 ... 1497 1498 1499]
# 442 out of [   1    2    3 ... 1497 1498 1499]
# 443 out of [   1    2    3 ... 1497 1498 1499]
# 444 out of [   1    2    3 ... 1497 1498 1499]
# 445 out of [   1    2    3 ... 1497 1498 1499]
# 446 out of [   1    2    3 ... 1497 1498 1499]
# 447 out of [   1    2    3 ... 1497 1498 1499]
# 448 out of [   1    2    3 ... 1497 1498 1499]
# 449 out of [   1    2    3 ... 1497 1498 1499]
# 450 out of [   1    2    3 ... 1497 1498 1499]
# 451 out of [   1    2    3 ... 1497 1498 1499]
# 452 out of [   1    2    3 ... 1497 1498 1499]
# 453 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 453. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409481904146<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 454 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 454. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409498490400<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 455 out of [   1    2    3 ... 1497 1498 1499]
# 456 out of [   1    2    3 ... 1497 1498 1499]
# 457 out of [   1    2    3 ... 1497 1498 1499]
# 458 out of [   1    2    3 ... 1497 1498 1499]
# 459 out of [   1    2    3 ... 1497 1498 1499]
# 460 out of [   1    2    3 ... 1497 1498 1499]
# 461 out of [   1    2    3 ... 1497 1498 1499]
# 462 out of [   1    2    3 ... 1497 1498 1499]
# 463 out of [   1    2    3 ... 1497 1498 1499]
# 464 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 464. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409528104675<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 465 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 465. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409481906194<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 466 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 466. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409528104899<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 467 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 467. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409493804401<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 468 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 468. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409493804433<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 469 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 469. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409528104947<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 470 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 470. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409481906274<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 471 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 471. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409493804481<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 472 out of [   1    2    3 ... 1497 1498 1499]
# 473 out of [   1    2    3 ... 1497 1498 1499]
# 474 out of [   1    2    3 ... 1497 1498 1499]
# 475 out of [   1    2    3 ... 1497 1498 1499]
# 476 out of [   1    2    3 ... 1497 1498 1499]
# 477 out of [   1    2    3 ... 1497 1498 1499]
# 478 out of [   1    2    3 ... 1497 1498 1499]
# 479 out of [   1    2    3 ... 1497 1498 1499]
# 480 out of [   1    2    3 ... 1497 1498 1499]
# 481 out of [   1    2    3 ... 1497 1498 1499]
# 482 out of [   1    2    3 ... 1497 1498 1499]
# 483 out of [   1    2    3 ... 1497 1498 1499]
# 484 out of [   1    2    3 ... 1497 1498 1499]
# 485 out of [   1    2    3 ... 1497 1498 1499]
# 486 out of [   1    2    3 ... 1497 1498 1499]
# 487 out of [   1    2    3 ... 1497 1498 1499]
# 488 out of [   1    2    3 ... 1497 1498 1499]
# 489 out of [   1    2    3 ... 1497 1498 1499]
# 490 out of [   1    2    3 ... 1497 1498 1499]
# 491 out of [   1    2    3 ... 1497 1498 1499]
# 492 out of [   1    2    3 ... 1497 1498 1499]
# 493 out of [   1    2    3 ... 1497 1498 1499]
# 494 out of [   1    2    3 ... 1497 1498 1499]
# 495 out of [   1    2    3 ... 1497 1498 1499]
# 496 out of [   1    2    3 ... 1497 1498 1499]
# 497 out of [   1    2    3 ... 1497 1498 1499]
# 498 out of [   1    2    3 ... 1497 1498 1499]
# 499 out of [   1    2    3 ... 1497 1498 1499]
# 500 out of [   1    2    3 ... 1497 1498 1499]
# 501 out of [   1    2    3 ... 1497 1498 1499]
# 502 out of [   1    2    3 ... 1497 1498 1499]
# 503 out of [   1    2    3 ... 1497 1498 1499]
# 504 out of [   1    2    3 ... 1497 1498 1499]
# 505 out of [   1    2    3 ... 1497 1498 1499]
# 506 out of [   1    2    3 ... 1497 1498 1499]
# 507 out of [   1    2    3 ... 1497 1498 1499]
# 508 out of [   1    2    3 ... 1497 1498 1499]
# 509 out of [   1    2    3 ... 1497 1498 1499]
# 510 out of [   1    2    3 ... 1497 1498 1499]
# 511 out of [   1    2    3 ... 1497 1498 1499]
# 512 out of [   1    2    3 ... 1497 1498 1499]
# 513 out of [   1    2    3 ... 1497 1498 1499]
# 514 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 514. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516813140<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 515 out of [   1    2    3 ... 1497 1498 1499]
# 516 out of [   1    2    3 ... 1497 1498 1499]
# 517 out of [   1    2    3 ... 1497 1498 1499]
# 518 out of [   1    2    3 ... 1497 1498 1499]
# 519 out of [   1    2    3 ... 1497 1498 1499]
# 520 out of [   1    2    3 ... 1497 1498 1499]
# 521 out of [   1    2    3 ... 1497 1498 1499]
# 522 out of [   1    2    3 ... 1497 1498 1499]
# 523 out of [   1    2    3 ... 1497 1498 1499]
# 524 out of [   1    2    3 ... 1497 1498 1499]
# ...
# 1456 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1456. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409486082613<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1457 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1457. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516893860<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1458 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1458. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516894004<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1459 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1459. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522497526<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1460 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1460. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522497590<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1461 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1461. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522497606<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1462 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1462. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522497670<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1463 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1463. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409486083141<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1464 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1464. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522497782<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1465 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1465. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522497862<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1466 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1466. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522497974<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1467 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1467. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522498038<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1468 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1468. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522498118<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1469 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1469. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516894596<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1470 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1470. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522498150<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1471 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1471. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470229623<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1472 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1472. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522498182<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1473 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1473. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522498214<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1474 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1474. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409486083637<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1475 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1475. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516894772<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1476 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1476. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409486083813<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1477 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1477. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409486083877<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1478 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1478. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409486084005<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1479 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1479. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470229911<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1480 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1480. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516895156<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1481 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1481. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409486084389<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1482 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1482. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409486084629<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1483 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1483. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409486084773<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1484 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1484. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470230247<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1485 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1485. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522499206<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1486 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1486. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470230263<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1487 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1487. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516895540<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1488 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1488. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409486084917<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1489 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1489. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516895572<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1490 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1490. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522499414<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1491 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1491. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470230423<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1492 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1492. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522499574<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1493 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1493. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470230519<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1494 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1494. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470230599<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1495 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1495. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409516896340<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1496 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1496. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470230759<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1497 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1497. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409486085573<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1498 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1498. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409470230999<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# 1499 out of [   1    2    3 ... 1497 1498 1499]
# Failed to decode JSON for ID 1499. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409522500102<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"

# %%
import pandas as pd

data = {
    "project_name": project_name_list,
    "country": country_list,
    "year": year_list,
    "sector": sector_list,
    "subsector": subsector_list,
    "investment": investment_list,
    "fund_source": fund_source_list,
    "carrier_type": carrier_type_list,
    "overall_rating": overall_list,
    "relevance": relevance_list,
    "coherence": coherence_list,
    "effectivity": effectivity_list,
    "efficiency": efficiency_list,
    "impact": impact_list,
    "sustainability": sustainability_list,
    "url": url_list,
    "outcome_fully": outcome_fully,
    "outcome_partially": outcome_partially,
    "outcome_not": outcome_not
}

project_data = pd.DataFrame(data)

# %%
# Add a column for pdf name from url column
project_data['pdf'] = project_data['url'].str.extract(r'/([^/]+\.pdf)$')

# %%
project_data.head()
# Out:
#                                         project_name  \
# 0  Renaturierung und nachhaltiges Management von ...
# 1                  Sektorreformprogramm Umwelt (PGF)
# 2  Schutzgebiete <span lang='en'>Guiana Shield</s...
# 3                                   Tropenwaldschutz
# 4    Bwabwata Mudumu Mamili National Parks (BMMP) II
#
#                     country  year        sector  \
# 0                   Ukraine  2019  Umweltschutz
# 1                      Peru  2018  Umweltschutz
# 2  Lateinamerika (regional)  2017  Umweltschutz
# 3                    Guyana  2015  Umweltschutz
# 4                   Namibia  2018  Umweltschutz
#
#                        subsector  investment  \
# 0  Ressourcenschutz inkl. Wasser   2678000.0
# 1  Ressourcenschutz inkl. Wasser  87000000.0
# 2  Ressourcenschutz inkl. Wasser   2970000.0
# 3  Ressourcenschutz inkl. Wasser   2750000.0
# 4  Ressourcenschutz inkl. Wasser   4410000.0
#
#                                          fund_source carrier_type  \
# 0  Bundesministerium für Umwelt, Naturschutz, nuk...          NRO
# 1  Bundesministerium für wirtschaftliche Zusammen...    Staatlich
# 2  Bundesministerium für Umwelt, Naturschutz, nuk...          NRO
# 3  Bundesministerium für wirtschaftliche Zusammen...    Staatlich
# 4  Bundesministerium für wirtschaftliche Zusammen...    Staatlich
#
#    overall_rating  relevance  coherence  effectivity  efficiency  impact  \
# 0               5        4.0        4.0          5.0         5.0       5
# 1               2        2.0        NaN          2.0         3.0       2
# 2               3        3.0        3.0          3.0         3.0       3
# 3               3        2.0        NaN          3.0         2.0       3
# 4               2        2.0        NaN          1.0         2.0       1
#
#    sustainability                                                url  \
# 0             4.0  https://www.kfw-entwicklungsbank.de/PDF/Evalui...
# 1             2.0  https://www.kfw-entwicklungsbank.de/PDF/Evalui...
# 2             3.0  https://www.kfw-entwicklungsbank.de/PDF/Evalui...
# 3             3.0  https://www.kfw-entwicklungsbank.de/PDF/Evalui...
# 4             2.0  https://www.kfw-entwicklungsbank.de/PDF/Evalui...
#
#    outcome_fully  outcome_partially  outcome_not  \
# 0       0.000000           0.000000   100.000000
# 1      80.000000          20.000000     0.000000
# 2      16.666667          83.333333     0.000000
# 3      33.333333          50.000000    16.666667
# 4      75.000000          25.000000     0.000000
#
#                                        pdf
# 0            IKI_Ukraine_Mooren_2019_D.pdf
# 1                Peru_SBHUmwelt_2018_D.pdf
# 2  IKI_Guyana_Shield_Initiative_2017_D.pdf
# 3       Guyana_Tropenwaldschutz_2015_D.pdf
# 4                  Namibia_BMMP_2018_D.pdf

# %%
project_data.to_csv("project_data.csv", index=False)
