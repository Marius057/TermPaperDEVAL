# %% [markdown]
# In this file, we:
#
# - Use the API to extract meta-data for every project
#
# **Result: project_data.csv**

# %%
import requests
import numpy as np

ids = np.arange(1, 1500, 1)

# API Url
base_url = "https://www.kfw-entwicklungsbank.de/kfw-ideal-service/api/projects/detail/DE/highRes/"

# Function to get project details for a given ID
def get_project_details(project_id):
    url = f"{base_url}{project_id}"
    response = requests.get(url)
    if response.status_code == 200:
        try:
            return response.json()
        except ValueError:
            print(f"Failed to decode JSON for ID {project_id}. Response content: {response.content}")
            return None
    else:
        print(f"Failed to retrieve data for ID {project_id}. Status code: {response.status_code}")
        return None

project_name_list = []
country_list = []
year_list = []
sector_list = []
subsector_list = []
investment_list = []
fund_source_list = []
carrier_type_list = []
overall_list = []
relevance_list = []
coherence_list = []
effectivity_list = []
efficiency_list = []
impact_list = []
sustainability_list = []
url_list = []

for project_id in ids:
    project_details = get_project_details(project_id)
    if project_details:
        
        project_name = project_details.get('projectName', 'N/A')
        country = project_details.get('country', 'N/A')
        year = project_details.get('year', 'N/A')
        sector = project_details.get('sector', 'N/A')
        subsector = project_details.get('sector2', 'N/A')
        investment = project_details.get('investment', 'N/A')
        fund_source = project_details.get('sourceOfFounds', 'N/A')
        carrier_type = project_details.get('carrierType', 'N/A')
        rating = project_details.get('rating', {})
        overall = rating.get('overall', 'N/A')
        relevance = rating.get('relevance', 'N/A')
        coherence = rating.get('coherence', 'N/A')
        effectivity = rating.get('effectivity', 'N/A')
        efficiency = rating.get('efficiency', 'N/A')
        impact = rating.get('impact', 'N/A')
        sustainability = rating.get('sustainability', 'N/A')
        url = project_details.get('reportUrl', 'N/A')
        
        project_name_list.append(project_name)
        country_list.append(country)
        year_list.append(year)
        sector_list.append(sector)
        subsector_list.append(subsector)
        investment_list.append(investment)
        fund_source_list.append(fund_source)
        carrier_type_list.append(carrier_type)
        overall_list.append(overall)
        relevance_list.append(relevance)
        coherence_list.append(coherence)
        effectivity_list.append(effectivity)
        efficiency_list.append(efficiency)
        impact_list.append(impact)
        sustainability_list.append(sustainability)
        url_list.append(url)
# Out:
# Failed to decode JSON for ID 23. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409345403958<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 60. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409345405606<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 61. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409345405638<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 62. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409350173123<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 63. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409350173203<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 64. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409350173315<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 65. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409350173347<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 67. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409350173427<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 68. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409323462225<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 69. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409350173507<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 70. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409323462385<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 71. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409350173555<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 80. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409350174179<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 81. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409309007010<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 82. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409309007106<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 83. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409309007186<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 84. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409323463089<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 85. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409309007266<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 106. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409323464321<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 123. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409340105716<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 149. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409340107124<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 150. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409313420485<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 151. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409340107156<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 152. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409345409958<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 153. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409340107220<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 154. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409345410038<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 155. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409340107252<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 156. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409300284647<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 157. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409345410134<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 158. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409340107764<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 159. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409313421237<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 160. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409313421397<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 172. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409300285575<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 181. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409340109796<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 182. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409340109828<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 183. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409340109844<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 184. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409345412262<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 195. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409350178947<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 207. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409323178464<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID
br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 1489. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409340164660<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 1490. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409300333447<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 1491. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409340164724<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 1492. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409300333463<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 1493. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409340164820<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 1494. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409313477861<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 1495. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409345464902<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 1496. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409313477877<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 1497. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409345465062<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 1498. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409313477909<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
# Failed to decode JSON for ID 1499. Response content: b"<html><head><title>Request Rejected</title></head><body>KfW - The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 13672170409313477989<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"

# %%
import pandas as pd

data = {
    "project_name": project_name_list,
    "country": country_list,
    "year": year_list,
    "sector": sector_list,
    "subsector": subsector_list,
    "investment": investment_list,
    "fund_source": fund_source_list,
    "carrier_type": carrier_type_list,
    "overall_rating": overall_list,
    "relevance": relevance_list,
    "coherence": coherence_list,
    "effectivity": effectivity_list,
    "efficiency": efficiency_list,
    "impact": impact_list,
    "sustainability": sustainability_list,
    "url": url_list
}

project_data = pd.DataFrame(data)

# %%
# Add a column for pdf name from url column
project_data['pdf'] = project_data['url'].str.extract(r'/([^/]+\.pdf)$')

# %%
project_data.head()
# Out:
#                                         project_name  \
# 0  Renaturierung und nachhaltiges Management von ...
# 1                  Sektorreformprogramm Umwelt (PGF)
# 2  Schutzgebiete <span lang='en'>Guiana Shield</s...
# 3                                   Tropenwaldschutz
# 4    Bwabwata Mudumu Mamili National Parks (BMMP) II
#
#                     country  year        sector  \
# 0                   Ukraine  2019  Umweltschutz
# 1                      Peru  2018  Umweltschutz
# 2  Lateinamerika (regional)  2017  Umweltschutz
# 3                    Guyana  2015  Umweltschutz
# 4                   Namibia  2018  Umweltschutz
#
#                        subsector  investment  \
# 0  Ressourcenschutz inkl. Wasser   2678000.0
# 1  Ressourcenschutz inkl. Wasser  87000000.0
# 2  Ressourcenschutz inkl. Wasser   2970000.0
# 3  Ressourcenschutz inkl. Wasser   2750000.0
# 4  Ressourcenschutz inkl. Wasser   4410000.0
#
#                                          fund_source carrier_type  \
# 0  Bundesministerium für Umwelt, Naturschutz, nuk...          NRO
# 1  Bundesministerium für wirtschaftliche Zusammen...    Staatlich
# 2  Bundesministerium für Umwelt, Naturschutz, nuk...          NRO
# 3  Bundesministerium für wirtschaftliche Zusammen...    Staatlich
# 4  Bundesministerium für wirtschaftliche Zusammen...    Staatlich
#
#    overall_rating  relevance  coherence  effectivity  efficiency  impact  \
# 0               5        4.0        4.0          5.0         5.0       5
# 1               2        2.0        NaN          2.0         3.0       2
# 2               3        3.0        3.0          3.0         3.0       3
# 3               3        2.0        NaN          3.0         2.0       3
# 4               2        2.0        NaN          1.0         2.0       1
#
#    sustainability                                                url  \
# 0             4.0  https://www.kfw-entwicklungsbank.de/PDF/Evalui...
# 1             2.0  https://www.kfw-entwicklungsbank.de/PDF/Evalui...
# 2             3.0  https://www.kfw-entwicklungsbank.de/PDF/Evalui...
# 3             3.0  https://www.kfw-entwicklungsbank.de/PDF/Evalui...
# 4             2.0  https://www.kfw-entwicklungsbank.de/PDF/Evalui...
#
#                                        pdf
# 0            IKI_Ukraine_Mooren_2019_D.pdf
# 1                Peru_SBHUmwelt_2018_D.pdf
# 2  IKI_Guyana_Shield_Initiative_2017_D.pdf
# 3       Guyana_Tropenwaldschutz_2015_D.pdf
# 4                  Namibia_BMMP_2018_D.pdf

# %%
project_data.to_csv("project_data.csv", index=False)
